# %%
import pandas as pd
import datetime as dt
import footballData as fd
import numpy as np
import random
import matplotlib.pyplot as plt
import datetime
import time
from numpy.polynomial.polynomial import polyfit

import Elo as ELO
import seaborn as sns

# %%
Comp=pd.read_csv('ELOComparison.csv')

# %%
plt.scatter( x=Comp['ClubELO'],y= Comp['AndrewELO'], marker='*', color='Red')
plt.xlabel('Club ELO Ratings')
plt.ylabel('Andrew ELO Ratings')
plt.title('ClubELO vs Andrew Ratings')
b, m = polyfit(Comp['ClubELO'], Comp['AndrewELO'], 1)

plt.plot(Comp['ClubELO'], b + m * Comp['ClubELO'], '-')
#plt.savefig('AndrewvsActual')
plt.show()

# %%
np.corrcoef(Comp['ClubELO'], Comp['AndrewELO'])
# Out:
# array([[ 1.        ,  0.98991827],
#        [ 0.98991827,  1.        ]])

# %%
m
# Out:
# 0.95005695955737202
