# %%
import pandas as pd
import datetime as dt
import footballData as fd
import numpy as np
import random
import matplotlib.pyplot as plt
import datetime
import time
import Elo as ELO

# %%
df1888=pd.read_csv('engsoccerdata2.csv')
# Out:
# /Users/andrewpuopolo/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in range(len(df1888)):
    if(df1888['Season'][i]>2003.5 and df1888['home'][i]=='Milton Keynes Dons'):
        df1888['home'][i]='Wimbledon'
    if(df1888['Season'][i]>2003.5 and df1888['visitor'][i]=='Milton Keynes Dons'):
        df1888['visitor'][i]='Wimbledon'
# Out:
# /Users/andrewpuopolo/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/andrewpuopolo/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
startdate=1983

fulldf=df1888[df1888['Season']>=startdate]
fulldf=fulldf.sort_values('Date')
fulldf=fulldf.reset_index()
del fulldf['index']

# %%
teamsstart=fulldf[fulldf['Season']==startdate]

# %%
initialrows=[]
for i in range(len(teamsstart['home'].unique())):
    Team=teamsstart['home'].unique()[i]
    Teamdf=teamsstart[teamsstart['home']==Team].reset_index()
    Tier=int(Teamdf['tier'][0])
    initialrow=[Team, Tier]
    initialrows.append(initialrow)
print(initialrows)
# Out:
# [['West Ham United', 1], ['Crystal Palace', 2], ['Aston Villa', 1], ['Grimsby Town', 2], ['Rochdale', 4], ['Exeter City', 3], ['Chesterfield', 4], ['Leeds United', 2], ['Nottingham Forest', 1], ['Chester', 4], ['Oldham Athletic', 2], ['Portsmouth', 2], ['Stockport County', 4], ['Bristol City', 4], ['Manchester United', 1], ['Sheffield United', 3], ['Blackpool', 4], ['Swansea City', 2], ['Leyton Orient', 3], ['AFC Bournemouth', 3], ['Aldershot', 4], ['Bolton Wanderers', 3], ['Leicester City', 1], ['Hull City', 3], ['Brentford', 3], ['Southend United', 3], ['Ipswich Town', 1], ['Tranmere Rovers', 4], ['Darlington', 4], ['Chelsea', 2], ['Everton', 1], ['Blackburn Rovers', 2], ['Port Vale', 3], ['Sunderland', 1], ['Oxford United', 3], ['Barnsley', 2], ['Plymouth Argyle', 3], ['Watford', 1], ['Arsenal', 1], ['Carlisle United', 2], ['Wolverhampton Wanderers', 1], ['Halifax Town', 4], ['Doncaster Rovers', 4], ['Charlton Athletic', 2], ['Newport County', 3], ['Peterborough United', 4], ['Newcastle United', 2], ['Cardiff City', 2], ['Tottenham Hotspur', 1], ['Derby County', 2], ['Southampton', 1], ['Stoke City', 1], ['Notts County', 1], ['Norwich City', 1], ['Hereford United', 4], ['Northampton Town', 4], ['Liverpool', 1], ['Wimbledon', 3], ['West Bromwich Albion', 1], ['Bristol Rovers', 3], ['Torquay United', 4], ['Burnley', 3], ['Mansfield Town', 4], ['Walsall', 3], ['Bradford City', 3], ['Wigan Athletic', 3], ['Cambridge United', 2], ['Shrewsbury Town', 2], ['Reading', 4], ['Crewe Alexandra', 4], ['Fulham', 2], ['Huddersfield Town', 2], ['Queens Park Rangers', 1], ['Manchester City', 2], ['Middlesbrough', 2], ['Bury', 4], ['Sheffield Wednesday', 2], ['Hartlepool United', 4], ['Brighton & Hove Albion', 2], ['Swindon Town', 4], ['Luton Town', 1], ['Colchester United', 4], ['Scunthorpe United', 3], ['York City', 4], ['Wrexham', 4], ['Gillingham', 3], ['Millwall', 3], ['Lincoln City', 3], ['Rotherham United', 3], ['Birmingham City', 1], ['Coventry City', 1], ['Preston North End', 3]]

# %%
Elodictionary={}
initvalues=[1750,1500,1250,1000]
HFA=80
k=20
L2Pro=950

# %%
for a in range(len(initialrows)):
    Elodictionary[initialrows[a][0]]=initvalues[initialrows[a][1]-1]

# %%
#Find Optimal K
logliksums=[]
burnin=[]
ks=[]
lengths=[]
for b in range(2,14):
    for k in range(15,27,1):
        print([k, b])
        Briers=[]
        logliks=[]
        BurnIn=b
        Elodictionary={}
        initvalues=[1750,1500,1250,1000]
        HFA=70
        L2Pro=950
        for a in range(len(initialrows)):
            Elodictionary[initialrows[a][0]]=initvalues[initialrows[a][1]-1]
        for j in range(len(fulldf)):
            Home=fulldf['home'][j]
            Away=fulldf['visitor'][j]
            Division=fulldf['tier'][j]-1
            if Home in Elodictionary:
                HomeELO=Elodictionary[Home]
            else:
                Elodictionary[Home]=L2Pro
                HomeELO=Elodictionary[Home]
            if Away in Elodictionary:
                AwayELO=Elodictionary[Away]
            else:
                Elodictionary[Away]=L2Pro
                AwayELO=Elodictionary[Away]
            Elodif=float((HomeELO-AwayELO+HFA)/400)
            E=1/(10**(-1*(Elodif))+1)
            if fulldf['hgoal'][j]>fulldf['vgoal'][j]:
                R=1
                MatchLogLik=np.log(E)
            elif fulldf['hgoal'][j]<fulldf['vgoal'][j]:
                R=0
                MatchLogLik=np.log(1-E)
            else:
                R=.5
                MatchLogLik=np.log(np.sqrt(E*(1-E)))
            PointExchange=(R-E)*k
            Elodictionary[Home]=HomeELO+PointExchange
            Elodictionary[Away]=AwayELO-PointExchange
            if fulldf['Season'][j]>(1982+b):
                logliks.append(MatchLogLik)
        logliksums.append(np.sum(logliks))
        ks.append(k)
        burnin.append(b)
        lengths.append(len(logliks))
# Out:
# [15, 2]
# [16, 2]
# [17, 2]
# [18, 2]
# [19, 2]
# [20, 2]
# [21, 2]
# [22, 2]
# [23, 2]
# [24, 2]
# [25, 2]
# [26, 2]
# [15, 3]
# [16, 3]
# [17, 3]
# [18, 3]
# [19, 3]
# [20, 3]
# [21, 3]
# [22, 3]
# [23, 3]
# [24, 3]
# [25, 3]
# [26, 3]
# [15, 4]
# [16, 4]
# [17, 4]
# [18, 4]
# [19, 4]
# [20, 4]
# [21, 4]
# [22, 4]
# [23, 4]
# [24, 4]
# [25, 4]
# [26, 4]
# [15, 5]
# [16, 5]
# [17, 5]
# [18, 5]
# [19, 5]
# [20, 5]
# [21, 5]
# [22, 5]
# [23, 5]
# [24, 5]
# [25, 5]
# [26, 5]
# [15, 6]
# [16, 6]
# [17, 6]
# [18, 6]
# [19, 6]
# [20, 6]
# [21, 6]
# [22, 6]
# [23, 6]
# [24, 6]
# [25, 6]
# [26, 6]
# [15, 7]
# [16, 7]
# [17, 7]
# [18, 7]
# [19, 7]
# [20, 7]
# [21, 7]
# [22, 7]
# [23, 7]
# [24, 7]
# [25, 7]
# [26, 7]
# [15, 8]
# [16, 8]
# [17, 8]
# [18, 8]
# [19, 8]
# [20, 8]
# [21, 8]
# [22, 8]
# [23, 8]
# [24, 8]
# [25, 8]
# [26, 8]
# [15, 9]
# [16, 9]
# [17, 9]
# [18, 9]
# [19, 9]
# [20, 9]
# [21, 9]
# [22, 9]
# [23, 9]
# [24, 9]
# [25, 9]
# [26, 9]
# [15, 10]
# [16, 10]
# [17, 10]
# [18, 10]
# [19, 10]
# [20, 10]
# [21, 10]
# [22, 10]
# [23, 10]
# [24, 10]
# [25, 10]
# [26, 10]
# [15, 11]
# [16, 11]
# [17, 11]
# [18, 11]
# [19, 11]
# [20, 11]
# [21, 11]
# [22, 11]
# [23, 11]
# [24, 11]
# [25, 11]
# [26, 11]
# [15, 12]
# [16, 12]
# [17, 12]
# [18, 12]
# [19, 12]
# [20, 12]
# [21, 12]
# [22, 12]
# [23, 12]
# [24, 12]
# [25, 12]
# [26, 12]
# [15, 13]
# [16, 13]
# [17, 13]
# [18, 13]
# [19, 13]
# [20, 13]
# [21, 13]
# [22, 13]
# [23, 13]
# [24, 13]
# [25, 13]
# [26, 13]

# %%
rows=[]
cols=['k', 'burn in','loglik', 'Length']
for i in range(len(ks)):
    rows.append([ks[i], burnin[i], logliksums[i], lengths[i]])
plottingdf=pd.DataFrame(rows, columns=cols)

# %%
plottingdf
# Out:
#       k  burn in        loglik  Length
# 0    15        2 -39354.452641   58990
# 1    16        2 -39321.948658   58990
# 2    17        2 -39295.763002   58990
# 3    18        2 -39274.963143   58990
# 4    19        2 -39258.799566   58990
# 5    20        2 -39246.661876   58990
# 6    21        2 -39238.047170   58990
# 7    22        2 -39232.536804   58990
# 8    23        2 -39229.779056   58990
# 9    24        2 -39229.475975   58990
# 10   25        2 -39231.373276   58990
# 11   26        2 -39235.252471   58990
# 12   15        3 -37985.755181   56962
# 13   16        3 -37959.080586   56962
# 14   17        3 -37937.884467   56962
# 15   18        3 -37921.361600   56962
# 16   19        3 -37908.867907   56962
# 17   20        3 -37899.880556   56962
# 18   21        3 -37893.969590   56962
# 19   22        3 -37890.777363   56962
# 20   23        3 -37890.003353   56962
# 21   24        3 -37891.392755   56962
# 22   25        3 -37894.727796   56962
# 23   26        3 -37899.821018   56962
# 24   15        4 -36618.897138   54934
# 25   16        4 -36596.343100   54934
# 26   17        4 -36578.644539   54934
# 27   18        4 -36565.103814   54934
# 28   19        4 -36555.161765   54934
# 29   20        4 -36548.363140   54934
# ..   ..      ...           ...     ...
# 114  21       11 -27040.874567   40712
# 115  22       11 -27041.825210   40712
# 116  23       11 -27044.247533   40712
# 117  24       11 -27047.990581   40712
# 118  25       11 -27052.924611   40712
# 119  26       11 -27058.937416   40712
# 120  15       12 -25736.785900   38684
# 121  16       12 -25724.944738   38684
# 122  17       12 -25716.130122   38684
# 123  18       12 -25709.914693   38684
# 124  19       12 -25705.952929   38684
# 125  20       12 -25703.961729   38684
# 126  21       12 -25703.706427   38684
# 127  22       12 -25704.990512   38684
# 128  23       12 -25707.647939   38684
# 129  24       12 -25711.537281   38684
# 130  25       12 -25716.537213   38684
# 131  26       12 -25722.542981   38684
# 132  15       13 -24373.241155   36648
# 133  16       13 -24362.482403   36648
# 134  17       13 -24354.585477   36648
# 135  18       13 -24349.139826   36648
# 136  19       13 -24345.814809   36648
# 137  20       13 -24344.340535   36648
# 138  21       13 -24344.494073   36648
# 139  22       13 -24346.089334   36648
# 140  23       13 -24348.969525   36648
# 141  24       13 -24353.001421   36648
# 142  25       13 -24358.070976   36648
# 143  26       13 -24364.079894   36648
#
# [144 rows x 4 columns]

# %%
minkrow=[]
cols2=['k', 'Min LogLik']
for i in range(2,14):
    newdf=plottingdf[plottingdf['burn in']==i].reset_index()
    loglikmin=newdf.loc[newdf['loglik'].idxmax()]
    print(loglikmin['burn in'], loglikmin['k'])
    minkrow.append([loglikmin['burn in'], loglikmin['k']])

minks=pd.DataFrame(minkrow,columns=cols2)
# Out:
# 2.0 24.0
# 3.0 23.0
# 4.0 22.0
# 5.0 22.0
# 6.0 22.0
# 7.0 22.0
# 8.0 21.0
# 9.0 21.0
# 10.0 21.0
# 11.0 21.0
# 12.0 21.0
# 13.0 20.0

# %%
minks['Min LogLik'].plot(kind='line', color='red', label='Log Likelihood', legend=True)
plt.xlabel('Burn In Period')
plt.ylabel('Optimal k')
plt.title('Optimal k by Burn In Period Using Log Likelihood and Brier as Inputs')
plt.show()

# %%
for j in range(2,14):
    newdf=plottingdf[plottingdf['burn in']==j].reset_index()
    x=newdf['k']
    y=newdf['loglik']
    plt.plot(x, y)
    plt.xlabel('K')
    plt.ylabel('Log Likelihood')
    plt.title('Log Likelihood/Brier by k with Burn In Period Of ' + str(j) + ' Years')
    plt.show()

# %%
min[fulldf['Season']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-33a7f7fbafb9> in <module>()
# ----> 1 min[fulldf['Season']]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
min(fulldf['Season'])
# Out:
# 1983

# %%
fulldf[fulldf['Season']<min(fulldf['Season']+2)]
# Out:
#             Date  Season                 home                 visitor   FT  \
# 0     1983-08-27    1983      West Ham United         Birmingham City  4-0
# 1     1983-08-27    1983       Crystal Palace         Manchester City  0-2
# 2     1983-08-27    1983          Aston Villa    West Bromwich Albion  4-3
# 3     1983-08-27    1983         Grimsby Town         Shrewsbury Town  1-1
# 4     1983-08-27    1983             Rochdale         Crewe Alexandra  1-0
# 5     1983-08-27    1983          Exeter City                 Walsall  0-1
# 6     1983-08-27    1983         Chesterfield            Swindon Town  1-0
# 7     1983-08-27    1983         Leeds United        Newcastle United  0-1
# 8     1983-08-27    1983    Nottingham Forest             Southampton  0-1
# 9     1983-08-27    1983              Chester        Northampton Town  1-1
# 10    1983-08-27    1983      Oldham Athletic  Brighton & Hove Albion  1-0
# 11    1983-08-27    1983           Portsmouth           Middlesbrough  0-1
# 12    1983-08-27    1983     Stockport County               York City  0-2
# 13    1983-08-27    1983         Bristol City          Mansfield Town  4-0
# 14    1983-08-27    1983    Manchester United     Queens Park Rangers  3-1
# 15    1983-08-27    1983     Sheffield United              Gillingham  4-0
# 16    1983-08-27    1983            Blackpool                 Reading  1-0
# 17    1983-08-27    1983         Swansea City     Sheffield Wednesday  0-1
# 18    1983-08-27    1983        Leyton Orient           Bradford City  2-0
# 19    1983-08-27    1983      AFC Bournemouth       Preston North End  0-1
# 20    1983-08-27    1983            Aldershot         Hereford United  1-4
# 21    1983-08-27    1983     Bolton Wanderers               Wimbledon  2-0
# 22    1983-08-27    1983       Leicester City            Notts County  0-4
# 23    1983-08-27    1983            Hull City                 Burnley  4-1
# 24    1983-08-27    1983            Brentford                Millwall  2-2
# 25    1983-08-27    1983      Southend United        Rotherham United  2-2
# 26    1983-08-27    1983         Ipswich Town       Tottenham Hotspur  3-1
# 27    1983-08-27    1983      Tranmere Rovers                    Bury  1-1
# 28    1983-08-27    1983           Darlington       Colchester United  0-2
# 29    1983-08-27    1983              Chelsea            Derby County  5-0
# ...          ...     ...                  ...                     ...  ...
# 4026  1985-05-11    1984      Manchester City       Charlton Athletic  5-1
# 4027  1985-05-11    1984      Birmingham City            Leeds United  1-0
# 4028  1985-05-11    1984  Sheffield Wednesday         West Ham United  2-1
# 4029  1985-05-11    1984         Swansea City          Bristol Rovers  3-2
# 4030  1985-05-13    1984      AFC Bournemouth          Newport County  3-0
# 4031  1985-05-13    1984              Watford       Manchester United  5-1
# 4032  1985-05-13    1984    Huddersfield Town        Sheffield United  2-2
# 4033  1985-05-13    1984       Wigan Athletic                 Reading  1-1
# 4034  1985-05-14    1984              Reading              Gillingham  0-2
# 4035  1985-05-14    1984          Southampton               Liverpool  1-1
# 4036  1985-05-14    1984              Chelsea            Norwich City  1-2
# 4037  1985-05-14    1984       Bristol Rovers               York City  1-1
# 4038  1985-05-14    1984         Ipswich Town           Coventry City  0-0
# 4039  1985-05-14    1984           Darlington          Torquay United  1-0
# 4040  1985-05-14    1984             Rochdale          Mansfield Town  2-1
# 4041  1985-05-14    1984      West Ham United              Stoke City  5-1
# 4042  1985-05-14    1984    Tottenham Hotspur     Sheffield Wednesday  2-0
# 4043  1985-05-17    1984           Gillingham          Wigan Athletic  5-1
# 4044  1985-05-17    1984           Stoke City           Coventry City  0-1
# 4045  1985-05-17    1984            Aldershot                Rochdale  5-0
# 4046  1985-05-17    1984            Liverpool                 Watford  4-3
# 4047  1985-05-17    1984         Swansea City            Bristol City  0-0
# 4048  1985-05-17    1984    Tottenham Hotspur       Nottingham Forest  1-0
# 4049  1985-05-17    1984         Ipswich Town         West Ham United  0-1
# 4050  1985-05-19    1984            Brentford                Millwall  1-1
# 4051  1985-05-20    1984      West Ham United               Liverpool  0-3
# 4052  1985-05-23    1984              Everton               Liverpool  1-0
# 4053  1985-05-23    1984        Coventry City              Luton Town  1-0
# 4054  1985-05-26    1984        Coventry City                 Everton  4-1
# 4055  1985-05-28    1984           Luton Town                 Everton  2-0
#
#       hgoal  vgoal division  tier  totgoal  goaldif result
# 0         4      0        1     1        4        4      H
# 1         0      2        2     2        2       -2      A
# 2         4      3        1     1        7        1      H
# 3         1      1        2     2        2        0      D
# 4         1      0        4     4        1        1      H
# 5         0      1        3     3        1       -1      A
# 6         1      0        4     4        1        1      H
# 7         0      1        2     2        1       -1      A
# 8         0      1        1     1        1       -1      A
# 9         1      1        4     4        2        0      D
# 10        1      0        2     2        1        1      H
# 11        0      1        2     2        1       -1      A
# 12        0      2        4     4        2       -2      A
# 13        4      0        4     4        4        4      H
# 14        3      1        1     1        4        2      H
# 15        4      0        3     3        4        4      H
# 16        1      0        4     4        1        1      H
# 17        0      1        2     2        1       -1      A
# 18        2      0        3     3        2        2      H
# 19        0      1        3     3        1       -1      A
# 20        1      4        4     4        5       -3      A
# 21        2      0        3     3        2        2      H
# 22        0      4        1     1        4       -4      A
# 23        4      1        3     3        5        3      H
# 24        2      2        3     3        4        0      D
# 25        2      2        3     3        4        0      D
# 26        3      1        1     1        4        2      H
# 27        1      1        4     4        2        0      D
# 28        0      2        4     4        2       -2      A
# 29        5      0        2     2        5        5      H
# ...     ...    ...      ...   ...      ...      ...    ...
# 4026      5      1        2     2        6        4      H
# 4027      1      0        2     2        1        1      H
# 4028      2      1        1     1        3        1      H
# 4029      3      2        3     3        5        1      H
# 4030      3      0        3     3        3        3      H
# 4031      5      1        1     1        6        4      H
# 4032      2      2        2     2        4        0      D
# 4033      1      1        3     3        2        0      D
# 4034      0      2        3     3        2       -2      A
# 4035      1      1        1     1        2        0      D
# 4036      1      2        1     1        3       -1      A
# 4037      1      1        3     3        2        0      D
# 4038      0      0        1     1        0        0      D
# 4039      1      0        4     4        1        1      H
# 4040      2      1        4     4        3        1      H
# 4041      5      1        1     1        6        4      H
# 4042      2      0        1     1        2        2      H
# 4043      5      1        3     3        6        4      H
# 4044      0      1        1     1        1       -1      A
# 4045      5      0        4     4        5        5      H
# 4046      4      3        1     1        7        1      H
# 4047      0      0        3     3        0        0      D
# 4048      1      0        1     1        1        1      H
# 4049      0      1        1     1        1       -1      A
# 4050      1      1        3     3        2        0      D
# 4051      0      3        1     1        3       -3      A
# 4052      1      0        1     1        1        1      H
# 4053      1      0        1     1        1        1      H
# 4054      4      1        1     1        5        3      H
# 4055      2      0        1     1        2        2      H
#
# [4056 rows x 12 columns]

# %%
#Find Optimal K
logliksums=[]
burnin=[]
ks=[]
p=100
for k in range(0,60,1):
    print([k, b])
    Briers=[]
    logliks=[]
    BurnIn=b
    Elodictionary={}
    initvalues=[1750,1500,1250,1000]
    HFA=70
    L2Pro=950
    initlen=len(fulldf[fulldf['Season']<min(fulldf['Season']+2))
    for a in range(len(initialrows)):
        Elodictionary[initialrows[a][0]]=initvalues[initialrows[a][1]-1]
    for j in range(len(fulldf)):
        if(j>initlen):
           kfactor=k
        else:
           kfactor=
        Home=fulldf['home'][j]
        Away=fulldf['visitor'][j]
        Division=fulldf['tier'][j]-1
        if Home in Elodictionary:
            HomeELO=Elodictionary[Home]
        else:
            Elodictionary[Home]=L2Pro
            HomeELO=Elodictionary[Home]
        if Away in Elodictionary:
            AwayELO=Elodictionary[Away]
        else:
            Elodictionary[Away]=L2Pro
            AwayELO=Elodictionary[Away]
        Elodif=float((HomeELO-AwayELO+HFA)/400)
        E=1/(10**(-1*(Elodif))+1)
        if fulldf['hgoal'][j]>fulldf['vgoal'][j]:
            R=1
            MatchLogLik=np.log(E)
        elif fulldf['hgoal'][j]<fulldf['vgoal'][j]:
            R=0
            MatchLogLik=np.log(1-E)
        else:
            R=.5
            MatchLogLik=np.log(np.sqrt(E*(1-E)))
            PointExchange=(R-E)*k
            Elodictionary[Home]=HomeELO+PointExchange
            Elodictionary[Away]=AwayELO-PointExchange
        if fulldf['Season'][j]>(1982+b):
            logliks.append(MatchLogLik)
    logliksums.append(np.sum(logliks))
    ks.append(k)
